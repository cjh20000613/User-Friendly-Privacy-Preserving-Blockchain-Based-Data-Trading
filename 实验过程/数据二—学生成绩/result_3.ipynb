# %%
import pandas as pd
import numpy as np
import glob

folder_path = 'E:/anacoda_workspace/论文/新建文件夹 (2)/数据二—学生成绩/'  # 替换为实际的文件夹路径
file_pattern = 'result_3_experiment_*.xlsx'

# 获取符合规则的文件列表
file_list = glob.glob(f'{folder_path}{file_pattern}')

# %%
# 读取并合并文件
dfs = []
for file in file_list:
    df = pd.read_excel(file)
    dfs.append(df)

# 合并所有数据框
combined_df = pd.concat(dfs, ignore_index=True)

# 打印合并后的数据框
print(combined_df)
# Out:
#      RE_privacy1_3  RE_privacy2_3  RE_privacy3_3  RE_linear_privacy1_3  \
# 0         0.012948       0.011301       0.013122              0.092440
# 1         0.009337       0.008268       0.007875              0.092433
# 2         0.004724       0.006428       0.005159              0.092456
# 3         0.005720       0.005208       0.005278              0.079281
# 4         0.009357       0.009530       0.009305              0.091091
# ..             ...            ...            ...                   ...
# 845       0.000309       0.000165       0.000959              0.076553
# 846       0.000573       0.001104       0.000979              0.069431
# 847       0.000698       0.001071       0.001328              0.075895
# 848       0.000738       0.001264       0.001328              0.073269
# 849       0.000787       0.001447       0.001328              0.072912
#
#      RE_linear_privacy2_3  RE_linear_privacy3_3
# 0                0.095868              0.095656
# 1                0.100207              0.099222
# 2                0.095427              0.099526
# 3                0.085747              0.091398
# 4                0.089247              0.086143
# ..                    ...                   ...
# 845              0.077260              0.076395
# 846              0.073083              0.069693
# 847              0.075108              0.073980
# 848              0.070833              0.073980
# 849              0.072111              0.073980
#
# [850 rows x 6 columns]

# %%
test_df = combined_df
test_df
# Out:
#      RE_privacy1_3  RE_privacy2_3  RE_privacy3_3  RE_linear_privacy1_3  \
# 0         0.012948       0.011301       0.013122              0.092440
# 1         0.009337       0.008268       0.007875              0.092433
# 2         0.004724       0.006428       0.005159              0.092456
# 3         0.005720       0.005208       0.005278              0.079281
# 4         0.009357       0.009530       0.009305              0.091091
# ..             ...            ...            ...                   ...
# 845       0.000309       0.000165       0.000959              0.076553
# 846       0.000573       0.001104       0.000979              0.069431
# 847       0.000698       0.001071       0.001328              0.075895
# 848       0.000738       0.001264       0.001328              0.073269
# 849       0.000787       0.001447       0.001328              0.072912
#
#      RE_linear_privacy2_3  RE_linear_privacy3_3
# 0                0.095868              0.095656
# 1                0.100207              0.099222
# 2                0.095427              0.099526
# 3                0.085747              0.091398
# 4                0.089247              0.086143
# ..                    ...                   ...
# 845              0.077260              0.076395
# 846              0.073083              0.069693
# 847              0.075108              0.073980
# 848              0.070833              0.073980
# 849              0.072111              0.073980
#
# [850 rows x 6 columns]

# %%
selected_data_list = []

for i in range(0, 17):
    selected_rows = list(range(i, 833 + i, 17))
    selected_data = test_df.iloc[selected_rows]
    selected_data_list.append(selected_data)

# %%
# 使用列表推导和 mean 函数分别计算每个数据框的平均值
averages_list = [df.mean() for df in selected_data_list]
averages_list
# Out:
# [RE_privacy1_3           0.006497
#  RE_privacy2_3           0.006516
#  RE_privacy3_3           0.006976
#  RE_linear_privacy1_3    0.068640
#  RE_linear_privacy2_3    0.068037
#  RE_linear_privacy3_3    0.069592
#  dtype: float64,
#  RE_privacy1_3           0.005293
#  RE_privacy2_3           0.005067
#  RE_privacy3_3           0.005314
#  RE_linear_privacy1_3    0.064740
#  RE_linear_privacy2_3    0.065902
#  RE_linear_privacy3_3    0.066736
#  dtype: float64,
#  RE_privacy1_3           0.005766
#  RE_privacy2_3           0.005551
#  RE_privacy3_3           0.005429
#  RE_linear_privacy1_3    0.066716
#  RE_linear_privacy2_3    0.066376
#  RE_linear_privacy3_3    0.066192
#  dtype: float64,
#  RE_privacy1_3           0.005880
#  RE_privacy2_3           0.005736
#  RE_privacy3_3           0.005543
#  RE_linear_privacy1_3    0.062741
#  RE_linear_privacy2_3    0.063017
#  RE_linear_privacy3_3    0.063489
#  dtype: float64,
#  RE_privacy1_3           0.005705
#  RE_privacy2_3           0.005635
#  RE_privacy3_3           0.005624
#  RE_linear_privacy1_3    0.063140
#  RE_linear_privacy2_3    0.063391
#  RE_linear_privacy3_3    0.063878
#  dtype: float64,
#  RE_privacy1_3           0.005019
#  RE_privacy2_3           0.005302
#  RE_privacy3_3           0.005198
#  RE_linear_privacy1_3    0.063691
#  RE_linear_privacy2_3    0.062989
#  RE_linear_privacy3_3    0.062859
#  dtype: float64,
#  RE_privacy1_3           0.004896
#  RE_privacy2_3           0.004828
#  RE_privacy3_3           0.004972
#  RE_linear_privacy1_3    0.060203
#  RE_linear_privacy2_3    0.061718
#  RE_linear_privacy3_3    0.061163
#  dtype: float64,
#  RE_privacy1_3           0.004421
#  RE_privacy2_3           0.004447
#  RE_privacy3_3           0.004403
#  RE_linear_privacy1_3    0.061637
#  RE_linear_privacy2_3    0.061268
#  RE_linear_privacy3_3    0.061940
#  dtype: float64,
#  RE_privacy1_3           0.004199
#  RE_privacy2_3           0.004193
#  RE_privacy3_3           0.004237
#  RE_linear_privacy1_3    0.063323
#  RE_linear_privacy2_3    0.063548
#  RE_linear_privacy3_3    0.063655
#  dtype: float64,
#  RE_privacy1_3           0.004234
#  RE_privacy2_3           0.004129
#  RE_privacy3_3           0.004010
#  RE_linear_privacy1_3    0.064241
#  RE_linear_privacy2_3    0.064322
#  RE_linear_privacy3_3    0.064294
#  dtype: float64,
#  RE_privacy1_3           0.004086
#  RE_privacy2_3           0.004024
#  RE_privacy3_3           0.003981
#  RE_linear_privacy1_3    0.065247
#  RE_linear_privacy2_3    0.065718
#  RE_linear_privacy3_3    0.065249
#  dtype: float64,
#  RE_privacy1_3           0.003977
#  RE_privacy2_3           0.003927
#  RE_privacy3_3           0.003979
#  RE_linear_privacy1_3    0.066013
#  RE_linear_privacy2_3    0.066443
#  RE_linear_privacy3_3    0.066507
#  dtype: float64,
#  RE_privacy1_3           0.003701
#  RE_privacy2_3           0.003650
#  RE_privacy3_3           0.003748
#  RE_linear_privacy1_3    0.066066
#  RE_linear_privacy2_3    0.066133
#  RE_linear_privacy3_3    0.066264
#  dtype: float64,
#  RE_privacy1_3           0.003855
#  RE_privacy2_3           0.003852
#  RE_privacy3_3           0.003660
#  RE_linear_privacy1_3    0.066931
#  RE_linear_privacy2_3    0.067342
#  RE_linear_privacy3_3    0.067473
#  dtype: float64,
#  RE_privacy1_3           0.003518
#  RE_privacy2_3           0.003548
#  RE_privacy3_3           0.003650
#  RE_linear_privacy1_3    0.067947
#  RE_linear_privacy2_3    0.068003
#  RE_linear_privacy3_3    0.067502
#  dtype: float64,
#  RE_privacy1_3           0.003738
#  RE_privacy2_3           0.003678
#  RE_privacy3_3           0.003657
#  RE_linear_privacy1_3    0.067780
#  RE_linear_privacy2_3    0.067526
#  RE_linear_privacy3_3    0.067455
#  dtype: float64,
#  RE_privacy1_3           0.003588
#  RE_privacy2_3           0.003550
#  RE_privacy3_3           0.003657
#  RE_linear_privacy1_3    0.068701
#  RE_linear_privacy2_3    0.068225
#  RE_linear_privacy3_3    0.067455
#  dtype: float64]

# %%
# 使用 pd.concat 将平均值列表重新组合成一个数据框
result_df = pd.concat(averages_list, axis=1)
result_df_transposed = result_df.T
result_df_transposed
# Out:
#     RE_privacy1_3  RE_privacy2_3  RE_privacy3_3  RE_linear_privacy1_3  \
# 0        0.006497       0.006516       0.006976              0.068640
# 1        0.005293       0.005067       0.005314              0.064740
# 2        0.005766       0.005551       0.005429              0.066716
# 3        0.005880       0.005736       0.005543              0.062741
# 4        0.005705       0.005635       0.005624              0.063140
# 5        0.005019       0.005302       0.005198              0.063691
# 6        0.004896       0.004828       0.004972              0.060203
# 7        0.004421       0.004447       0.004403              0.061637
# 8        0.004199       0.004193       0.004237              0.063323
# 9        0.004234       0.004129       0.004010              0.064241
# 10       0.004086       0.004024       0.003981              0.065247
# 11       0.003977       0.003927       0.003979              0.066013
# 12       0.003701       0.003650       0.003748              0.066066
# 13       0.003855       0.003852       0.003660              0.066931
# 14       0.003518       0.003548       0.003650              0.067947
# 15       0.003738       0.003678       0.003657              0.067780
# 16       0.003588       0.003550       0.003657              0.068701
#
#     RE_linear_privacy2_3  RE_linear_privacy3_3
# 0               0.068037              0.069592
# 1               0.065902              0.066736
# 2               0.066376              0.066192
# 3               0.063017              0.063489
# 4               0.063391              0.063878
# 5               0.062989              0.062859
# 6               0.061718              0.061163
# 7               0.061268              0.061940
# 8               0.063548              0.063655
# 9               0.064322              0.064294
# 10              0.065718              0.065249
# 11              0.066443              0.066507
# 12              0.066133              0.066264
# 13              0.067342              0.067473
# 14              0.068003              0.067502
# 15              0.067526              0.067455
# 16              0.068225              0.067455

# %%
import matplotlib.pyplot as plt
# 实验三

# 选择要绘制的列
columns_to_plot = ['RE_privacy1_3', 'RE_privacy2_3', 'RE_privacy3_3']

# 预先设定不同列名对应的标签
column_labels = {'RE_privacy1_3': 'privacy_1', 'RE_privacy2_3': 'privacy_2', 'RE_privacy3_3':'privacy_3'}

# 获取列名作为 x 轴数据
x_values = np.linspace(0, 1, len(result_df_transposed.index))

# 获取每列的平均值作为 y 轴数据，并乘以 100
for column in columns_to_plot:
    y_values = result_df_transposed[column] * 100
    
    # 绘制曲线
    plt.plot(x_values, y_values, label=column_labels.get(column, column))

# 设置 x 轴范围为 [0, 1]
plt.xlim(0, 1)

# 设置 x 轴标签
plt.xlabel('Budget')

# 设置 y 轴标签
plt.ylabel('RE(%)')

# 添加图例
plt.legend()

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
# 实验三

# 选择要绘制的列
columns_to_plot = ['RE_linear_privacy1_3', 'RE_linear_privacy2_3', 'RE_linear_privacy3_3']

# 预先设定不同列名对应的标签
column_labels = {'RE_linear_privacy1_3': 'privacy_1', 'RE_linear_privacy2_3': 'privacy_2', 'RE_linear_privacy3_3':'privacy_3'}

# 获取列名作为 x 轴数据
x_values = np.linspace(0, 1, len(result_df_transposed.index))

# 获取每列的平均值作为 y 轴数据，并乘以 100
for column in columns_to_plot:
    y_values = result_df_transposed[column] * 100
    
    # 绘制曲线
    plt.plot(x_values, y_values, label=column_labels.get(column, column))

# 设置 x 轴范围为 [0, 1]
plt.xlim(0, 1)

# 设置 x 轴标签
plt.xlabel('Budget')

# 设置 y 轴标签
plt.ylabel('RE(%)')

# 添加图例
plt.legend()

# 显示图形
plt.show()
