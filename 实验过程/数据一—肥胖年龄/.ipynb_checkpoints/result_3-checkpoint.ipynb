# %%
import pandas as pd
import numpy as np
import glob

folder_path = 'E:/anacoda_workspace/论文/新建文件夹 (2)/数据一—肥胖年龄/'  # 替换为实际的文件夹路径
file_pattern = 'result_3_experiment_*.xlsx'

# 获取符合规则的文件列表
file_list = glob.glob(f'{folder_path}{file_pattern}')

# %%
# 读取并合并文件
dfs = []
for file in file_list:
    df = pd.read_excel(file)
    dfs.append(df)

# 合并所有数据框
combined_df = pd.concat(dfs, ignore_index=True)

# 打印合并后的数据框
print(combined_df)
# Out:
#      RE_privacy1_3  RE_privacy2_3  RE_privacy3_3  RE_linear_privacy1_3  \
# 0         0.000005       0.002982       0.000057              0.012074
# 1         0.000003       0.000606       0.000603              0.018937
# 2         0.000676       0.000258       0.000131              0.005414
# 3         0.001432       0.000810       0.001487              0.006345
# 4         0.002676       0.002056       0.002933              0.006302
# ..             ...            ...            ...                   ...
# 845       0.004190       0.004243       0.004333              0.010344
# 846       0.004436       0.003748       0.004095              0.010132
# 847       0.005379       0.004336       0.005370              0.011228
# 848       0.003389       0.003471       0.005193              0.003120
# 849       0.002567       0.002740       0.002777              0.008911
#
#      RE_linear_privacy2_3  RE_linear_privacy3_3
# 0                0.009249              0.018088
# 1                0.013797              0.012972
# 2                0.004555              0.006250
# 3                0.014649              0.009660
# 4                0.000095              0.002935
# ..                    ...                   ...
# 845              0.013396              0.015304
# 846              0.010595              0.006366
# 847              0.005995              0.009545
# 848              0.001846              0.006000
# 849              0.008895              0.009889
#
# [850 rows x 6 columns]

# %%
test_df = combined_df
test_df
# Out:
#      RE_privacy1_3  RE_privacy2_3  RE_privacy3_3  RE_linear_privacy1_3  \
# 0         0.000005       0.002982       0.000057              0.012074
# 1         0.000003       0.000606       0.000603              0.018937
# 2         0.000676       0.000258       0.000131              0.005414
# 3         0.001432       0.000810       0.001487              0.006345
# 4         0.002676       0.002056       0.002933              0.006302
# ..             ...            ...            ...                   ...
# 845       0.004190       0.004243       0.004333              0.010344
# 846       0.004436       0.003748       0.004095              0.010132
# 847       0.005379       0.004336       0.005370              0.011228
# 848       0.003389       0.003471       0.005193              0.003120
# 849       0.002567       0.002740       0.002777              0.008911
#
#      RE_linear_privacy2_3  RE_linear_privacy3_3
# 0                0.009249              0.018088
# 1                0.013797              0.012972
# 2                0.004555              0.006250
# 3                0.014649              0.009660
# 4                0.000095              0.002935
# ..                    ...                   ...
# 845              0.013396              0.015304
# 846              0.010595              0.006366
# 847              0.005995              0.009545
# 848              0.001846              0.006000
# 849              0.008895              0.009889
#
# [850 rows x 6 columns]

# %%
selected_data_list = []

for i in range(0, 17):
    selected_rows = list(range(i, 833 + i, 17))
    selected_data = test_df.iloc[selected_rows]
    selected_data_list.append(selected_data)

# %%
# 使用列表推导和 mean 函数分别计算每个数据框的平均值
averages_list = [df.mean() for df in selected_data_list]
averages_list
# Out:
# [RE_privacy1_3           0.005355
#  RE_privacy2_3           0.005629
#  RE_privacy3_3           0.005511
#  RE_linear_privacy1_3    0.082084
#  RE_linear_privacy2_3    0.085115
#  RE_linear_privacy3_3    0.083165
#  dtype: float64,
#  RE_privacy1_3           0.005420
#  RE_privacy2_3           0.005593
#  RE_privacy3_3           0.005541
#  RE_linear_privacy1_3    0.074483
#  RE_linear_privacy2_3    0.076119
#  RE_linear_privacy3_3    0.073929
#  dtype: float64,
#  RE_privacy1_3           0.004963
#  RE_privacy2_3           0.005244
#  RE_privacy3_3           0.005038
#  RE_linear_privacy1_3    0.068358
#  RE_linear_privacy2_3    0.068769
#  RE_linear_privacy3_3    0.066843
#  dtype: float64,
#  RE_privacy1_3           0.004636
#  RE_privacy2_3           0.004573
#  RE_privacy3_3           0.004532
#  RE_linear_privacy1_3    0.066313
#  RE_linear_privacy2_3    0.066416
#  RE_linear_privacy3_3    0.067302
#  dtype: float64,
#  RE_privacy1_3           0.004149
#  RE_privacy2_3           0.004219
#  RE_privacy3_3           0.004113
#  RE_linear_privacy1_3    0.062218
#  RE_linear_privacy2_3    0.061965
#  RE_linear_privacy3_3    0.063918
#  dtype: float64,
#  RE_privacy1_3           0.003926
#  RE_privacy2_3           0.003805
#  RE_privacy3_3           0.003820
#  RE_linear_privacy1_3    0.060013
#  RE_linear_privacy2_3    0.059864
#  RE_linear_privacy3_3    0.060336
#  dtype: float64,
#  RE_privacy1_3           0.003835
#  RE_privacy2_3           0.003839
#  RE_privacy3_3           0.003903
#  RE_linear_privacy1_3    0.058007
#  RE_linear_privacy2_3    0.058824
#  RE_linear_privacy3_3    0.058450
#  dtype: float64,
#  RE_privacy1_3           0.003743
#  RE_privacy2_3           0.003673
#  RE_privacy3_3           0.003866
#  RE_linear_privacy1_3    0.057391
#  RE_linear_privacy2_3    0.057533
#  RE_linear_privacy3_3    0.058218
#  dtype: float64,
#  RE_privacy1_3           0.003633
#  RE_privacy2_3           0.003495
#  RE_privacy3_3           0.003699
#  RE_linear_privacy1_3    0.054003
#  RE_linear_privacy2_3    0.054387
#  RE_linear_privacy3_3    0.053340
#  dtype: float64,
#  RE_privacy1_3           0.003317
#  RE_privacy2_3           0.003293
#  RE_privacy3_3           0.003401
#  RE_linear_privacy1_3    0.051389
#  RE_linear_privacy2_3    0.051643
#  RE_linear_privacy3_3    0.051266
#  dtype: float64,
#  RE_privacy1_3           0.003178
#  RE_privacy2_3           0.003321
#  RE_privacy3_3           0.003247
#  RE_linear_privacy1_3    0.049545
#  RE_linear_privacy2_3    0.049774
#  RE_linear_privacy3_3    0.050678
#  dtype: float64,
#  RE_privacy1_3           0.003111
#  RE_privacy2_3           0.003142
#  RE_privacy3_3           0.003061
#  RE_linear_privacy1_3    0.048945
#  RE_linear_privacy2_3    0.049497
#  RE_linear_privacy3_3    0.049679
#  dtype: float64,
#  RE_privacy1_3           0.003199
#  RE_privacy2_3           0.003131
#  RE_privacy3_3           0.003108
#  RE_linear_privacy1_3    0.047964
#  RE_linear_privacy2_3    0.047779
#  RE_linear_privacy3_3    0.048239
#  dtype: float64,
#  RE_privacy1_3           0.002986
#  RE_privacy2_3           0.002970
#  RE_privacy3_3           0.003025
#  RE_linear_privacy1_3    0.047838
#  RE_linear_privacy2_3    0.047963
#  RE_linear_privacy3_3    0.047918
#  dtype: float64,
#  RE_privacy1_3           0.002941
#  RE_privacy2_3           0.002923
#  RE_privacy3_3           0.002937
#  RE_linear_privacy1_3    0.048862
#  RE_linear_privacy2_3    0.048463
#  RE_linear_privacy3_3    0.048374
#  dtype: float64,
#  RE_privacy1_3           0.003025
#  RE_privacy2_3           0.002918
#  RE_privacy3_3           0.002971
#  RE_linear_privacy1_3    0.047585
#  RE_linear_privacy2_3    0.047567
#  RE_linear_privacy3_3    0.047597
#  dtype: float64,
#  RE_privacy1_3           0.003038
#  RE_privacy2_3           0.003050
#  RE_privacy3_3           0.003062
#  RE_linear_privacy1_3    0.047631
#  RE_linear_privacy2_3    0.047581
#  RE_linear_privacy3_3    0.046813
#  dtype: float64]

# %%
# 使用 pd.concat 将平均值列表重新组合成一个数据框
result_df = pd.concat(averages_list, axis=1)
result_df_transposed = result_df.T
result_df_transposed
# Out:
#     RE_privacy1_3  RE_privacy2_3  RE_privacy3_3  RE_linear_privacy1_3  \
# 0        0.005355       0.005629       0.005511              0.082084
# 1        0.005420       0.005593       0.005541              0.074483
# 2        0.004963       0.005244       0.005038              0.068358
# 3        0.004636       0.004573       0.004532              0.066313
# 4        0.004149       0.004219       0.004113              0.062218
# 5        0.003926       0.003805       0.003820              0.060013
# 6        0.003835       0.003839       0.003903              0.058007
# 7        0.003743       0.003673       0.003866              0.057391
# 8        0.003633       0.003495       0.003699              0.054003
# 9        0.003317       0.003293       0.003401              0.051389
# 10       0.003178       0.003321       0.003247              0.049545
# 11       0.003111       0.003142       0.003061              0.048945
# 12       0.003199       0.003131       0.003108              0.047964
# 13       0.002986       0.002970       0.003025              0.047838
# 14       0.002941       0.002923       0.002937              0.048862
# 15       0.003025       0.002918       0.002971              0.047585
# 16       0.003038       0.003050       0.003062              0.047631
#
#     RE_linear_privacy2_3  RE_linear_privacy3_3
# 0               0.085115              0.083165
# 1               0.076119              0.073929
# 2               0.068769              0.066843
# 3               0.066416              0.067302
# 4               0.061965              0.063918
# 5               0.059864              0.060336
# 6               0.058824              0.058450
# 7               0.057533              0.058218
# 8               0.054387              0.053340
# 9               0.051643              0.051266
# 10              0.049774              0.050678
# 11              0.049497              0.049679
# 12              0.047779              0.048239
# 13              0.047963              0.047918
# 14              0.048463              0.048374
# 15              0.047567              0.047597
# 16              0.047581              0.046813

# %%
import matplotlib.pyplot as plt
# 实验三

# 选择要绘制的列
columns_to_plot = ['RE_privacy1_3', 'RE_privacy2_3', 'RE_privacy3_3']

# 预先设定不同列名对应的标签
column_labels = {'RE_privacy1_3': 'privacy_1', 'RE_privacy2_3': 'privacy_2', 'RE_privacy3_3':'privacy_3'}

# 获取列名作为 x 轴数据
x_values = np.linspace(0, 1, len(result_df_transposed.index))

# 获取每列的平均值作为 y 轴数据，并乘以 100
for column in columns_to_plot:
    y_values = result_df_transposed[column] * 100
    
    # 绘制曲线
    plt.plot(x_values, y_values, label=column_labels.get(column, column))

# 设置 x 轴范围为 [0, 1]
plt.xlim(0, 1)

# 设置 x 轴标签
plt.xlabel('Budget')

# 设置 y 轴标签
plt.ylabel('RE(%)')

# 添加图例
plt.legend()

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
# 实验三

# 选择要绘制的列
columns_to_plot = ['RE_linear_privacy1_3', 'RE_linear_privacy2_3', 'RE_linear_privacy3_3']

# 预先设定不同列名对应的标签
column_labels = {'RE_linear_privacy1_3': 'privacy_1', 'RE_linear_privacy2_3': 'privacy_2', 'RE_linear_privacy3_3':'privacy_3'}

# 获取列名作为 x 轴数据
x_values = np.linspace(0, 1, len(result_df_transposed.index))

# 获取每列的平均值作为 y 轴数据，并乘以 100
for column in columns_to_plot:
    y_values = result_df_transposed[column] * 100
    
    # 绘制曲线
    plt.plot(x_values, y_values, label=column_labels.get(column, column))

# 设置 x 轴范围为 [0, 1]
plt.xlim(0, 1)

# 设置 x 轴标签
plt.xlabel('Budget')

# 设置 y 轴标签
plt.ylabel('RE(%)')

# 添加图例
plt.legend()

# 显示图形
plt.show()
