# %%
import pandas as pd
import numpy as np
import glob

folder_path = 'E:/anacoda_workspace/论文/新建文件夹 (2)/数据三—工作薪资/'  # 替换为实际的文件夹路径
file_pattern = 'result_12_experiment_*.xlsx'

# 获取符合规则的文件列表
file_list = glob.glob(f'{folder_path}{file_pattern}')

# %%
# 读取并合并文件
dfs = []
for file in file_list:
    df = pd.read_excel(file)
    dfs.append(df)

# 合并所有数据框
combined_df = pd.concat(dfs, ignore_index=True)

# 打印合并后的数据框
print(combined_df)
# Out:
#      RE_values_1  RE_LAP_values_1  RE_linear_values_1  RE_linear_LAP_values_1  \
# 0       0.002190         0.016029            0.443278                0.463404
# 1       0.002748         0.015865            0.328149                0.315855
# 2       0.000301         0.012529            0.330819                0.307815
# 3       0.001468         0.016656            0.321450                0.278190
# 4       0.001385         0.020444            0.301974                0.234641
# ..           ...              ...                 ...                     ...
# 995     0.002884         0.003859            0.255208                0.305468
# 996     0.003197         0.002138            0.259953                0.307868
# 997     0.003219         0.007713            0.261656                0.302404
# 998     0.002562         0.004936            0.253260                0.285346
# 999     0.002307         0.005089            0.253812                0.277124
#
#       VALUE_PDT_2    VALUE_FQ_2   VALUE_SMQ_2   RE_FQ_2  RE_linear_FQ_2  \
# 0      704.484314    589.978332    682.820351  0.000654        0.257669
# 1     1406.576537   1195.350935   1370.339126  0.002863        0.246495
# 2     2105.587029   1792.916579   2040.868765  0.004353        0.236328
# 3     2801.625144   2398.461673   2694.201839  0.005710        0.236128
# 4     3495.254086   2994.795216   3357.719863  0.005688        0.233628
# ..            ...           ...           ...       ...             ...
# 995  10917.501190   9502.530746  10365.461222  0.000482        0.235457
# 996  11571.397659  10054.831553  10974.249686  0.000314        0.232311
# 997  12220.627293  10645.004373  11571.379982  0.000197        0.237488
# 998  12864.691702  11239.139780  12200.894598  0.000258        0.239284
# 999  13505.056490  11830.268029  12789.469998  0.000570        0.242371
#
#      RE_SMQ_2  RE_linear_SMQ_2
# 0    0.000680         0.339042
# 1    0.000791         0.221098
# 2    0.004047         0.224146
# 3    0.004982         0.224585
# 4    0.005714         0.220073
# ..        ...              ...
# 995  0.002831         0.255221
# 996  0.002500         0.233056
# 997  0.001907         0.232005
# 998  0.002036         0.246138
# 999  0.000301         0.241349
#
# [1000 rows x 11 columns]

# %%
test_df = combined_df
test_df
# Out:
#      RE_values_1  RE_LAP_values_1  RE_linear_values_1  RE_linear_LAP_values_1  \
# 0       0.002190         0.016029            0.443278                0.463404
# 1       0.002748         0.015865            0.328149                0.315855
# 2       0.000301         0.012529            0.330819                0.307815
# 3       0.001468         0.016656            0.321450                0.278190
# 4       0.001385         0.020444            0.301974                0.234641
# ..           ...              ...                 ...                     ...
# 995     0.002884         0.003859            0.255208                0.305468
# 996     0.003197         0.002138            0.259953                0.307868
# 997     0.003219         0.007713            0.261656                0.302404
# 998     0.002562         0.004936            0.253260                0.285346
# 999     0.002307         0.005089            0.253812                0.277124
#
#       VALUE_PDT_2    VALUE_FQ_2   VALUE_SMQ_2   RE_FQ_2  RE_linear_FQ_2  \
# 0      704.484314    589.978332    682.820351  0.000654        0.257669
# 1     1406.576537   1195.350935   1370.339126  0.002863        0.246495
# 2     2105.587029   1792.916579   2040.868765  0.004353        0.236328
# 3     2801.625144   2398.461673   2694.201839  0.005710        0.236128
# 4     3495.254086   2994.795216   3357.719863  0.005688        0.233628
# ..            ...           ...           ...       ...             ...
# 995  10917.501190   9502.530746  10365.461222  0.000482        0.235457
# 996  11571.397659  10054.831553  10974.249686  0.000314        0.232311
# 997  12220.627293  10645.004373  11571.379982  0.000197        0.237488
# 998  12864.691702  11239.139780  12200.894598  0.000258        0.239284
# 999  13505.056490  11830.268029  12789.469998  0.000570        0.242371
#
#      RE_SMQ_2  RE_linear_SMQ_2
# 0    0.000680         0.339042
# 1    0.000791         0.221098
# 2    0.004047         0.224146
# 3    0.004982         0.224585
# 4    0.005714         0.220073
# ..        ...              ...
# 995  0.002831         0.255221
# 996  0.002500         0.233056
# 997  0.001907         0.232005
# 998  0.002036         0.246138
# 999  0.000301         0.241349
#
# [1000 rows x 11 columns]

# %%
selected_data_list = []

for i in range(0, 20):
    selected_rows = list(range(i, 981 + i, 20))
    selected_data = test_df.iloc[selected_rows]
    selected_data_list.append(selected_data)

# %%
# 使用列表推导和 mean 函数分别计算每个数据框的平均值
averages_list = [df.mean() for df in selected_data_list]
averages_list
# Out:
# [RE_values_1                 0.002328
#  RE_LAP_values_1             0.024715
#  RE_linear_values_1          0.264575
#  RE_linear_LAP_values_1      0.260995
#  VALUE_PDT_2               704.603651
#  VALUE_FQ_2                592.782326
#  VALUE_SMQ_2               682.351003
#  RE_FQ_2                     0.003633
#  RE_linear_FQ_2              0.264657
#  RE_SMQ_2                    0.004766
#  RE_linear_SMQ_2             0.258920
#  dtype: float64,
#  RE_values_1                  0.001670
#  RE_LAP_values_1              0.019786
#  RE_linear_values_1           0.252660
#  RE_linear_LAP_values_1       0.226123
#  VALUE_PDT_2               1406.649002
#  VALUE_FQ_2                1185.436815
#  VALUE_SMQ_2               1358.420167
#  RE_FQ_2                      0.003139
#  RE_linear_FQ_2               0.254200
#  RE_SMQ_2                     0.003274
#  RE_linear_SMQ_2              0.271811
#  dtype: float64,
#  RE_values_1                  0.001519
#  RE_LAP_values_1              0.015292
#  RE_linear_values_1           0.253457
#  RE_linear_LAP_values_1       0.236770
#  VALUE_PDT_2               2106.030590
#  VALUE_FQ_2                1777.532694
#  VALUE_SMQ_2               2029.537073
#  RE_FQ_2                      0.002919
#  RE_linear_FQ_2               0.251118
#  RE_SMQ_2                     0.002861
#  RE_linear_SMQ_2              0.254825
#  dtype: float64,
#  RE_values_1                  0.001429
#  RE_LAP_values_1              0.013931
#  RE_linear_values_1           0.255917
#  RE_linear_LAP_values_1       0.237210
#  VALUE_PDT_2               2802.596044
#  VALUE_FQ_2                2371.386173
#  VALUE_SMQ_2               2695.101438
#  RE_FQ_2                      0.002907
#  RE_linear_FQ_2               0.251552
#  RE_SMQ_2                     0.002523
#  RE_linear_SMQ_2              0.241754
#  dtype: float64,
#  RE_values_1                  0.001392
#  RE_LAP_values_1              0.013915
#  RE_linear_values_1           0.255456
#  RE_linear_LAP_values_1       0.242043
#  VALUE_PDT_2               3496.449059
#  VALUE_FQ_2                2964.385629
#  VALUE_SMQ_2               3352.711777
#  RE_FQ_2                      0.002799
#  RE_linear_FQ_2               0.251191
#  RE_SMQ_2                     0.002303
#  RE_linear_SMQ_2              0.249341
#  dtype: float64,
#  RE_values_1                  0.001394
#  RE_LAP_values_1              0.012175
#  RE_linear_values_1           0.257403
#  RE_linear_LAP_values_1       0.244656
#  VALUE_PDT_2               4187.484389
#  VALUE_FQ_2                3556.711965
#  VALUE_SMQ_2               4007.123314
#  RE_FQ_2                      0.002811
#  RE_linear_FQ_2               0.252257
#  RE_SMQ_2                     0.002375
#  RE_linear_SMQ_2              0.249199
#  dtype: float64,
#  RE_values_1                  0.001276
#  RE_LAP_values_1              0.010272
#  RE_linear_values_1           0.254136
#  RE_linear_LAP_values_1       0.244371
#  VALUE_PDT_2               4875.534411
#  VALUE_FQ_2                4148.220767
#  VALUE_SMQ_2               4656.160302
#  RE_FQ_2                      0.002849
#  RE_linear_FQ_2               0.251552
#  RE_SMQ_2                     0.002314
#  RE_linear_SMQ_2              0.250786
#  dtype: float64,
#  RE_values_1                  0.001112
#  RE_LAP_values_1              0.010166
#  RE_linear_values_1           0.252410
#  RE_linear_LAP_values_1       0.242251
#  VALUE_PDT_2               5560.533094
#  VALUE_FQ_2                4739.504369
#  VALUE_SMQ_2               5301.506989
#  RE_FQ_2                      0.002942
#  RE_linear_FQ_2               0.250981
#  RE_SMQ_2                     0.002106
#  RE_linear_SMQ_2              0.248804
#  dtype: float64,
#  RE_values_1                  0.001101
#  RE_LAP_values_1              0.009902
#  RE_linear_values_1           0.252664
#  RE_linear_LAP_values_1       0.246822
#  VALUE_PDT_2               6242.356160
#  VALUE_FQ_2                5332.079811
#  VALUE_SMQ_2               5942.679043
#  RE_FQ_2                      0.002802
#  RE_linear_FQ_2               0.249704
#  RE_SMQ_2                     0.002261
#  RE_linear_SMQ_2              0.249151
#  dtype: float64,
#  RE_values_1                  0.001139
#  RE_LAP_values_1              0.008862
#  RE_linear_values_1           0.252263
#  RE_linear_LAP_values_1       0.249009
#  VALUE_PDT_2               6921.033827
#  VALUE_FQ_2                5924.683005
#  VALUE_SMQ_2               6574.567324
#  RE_FQ_2                      0.002659
#  RE_linear_FQ_2               0.251041
#  RE_SMQ_2                     0.002237
#  RE_linear_SMQ_2              0.246373
#  dtype: float64,
#  RE_values_1                  0.001181
#  RE_LAP_values_1              0.008843
#  RE_linear_values_1           0.249194
#  RE_linear_LAP_values_1       0.247297
#  VALUE_PDT_2               7596.367548
#  VALUE_FQ_2                6516.379944
#  VALUE_SMQ_2               7207.893958
#  RE_FQ_2                      0.002663
#  RE_linear_FQ_2               0.252117
#  RE_SMQ_2                     0.002191
#  RE_linear_SMQ_2              0.245453
#  dtype: float64,
#  RE_values_1                  0.001181
#  RE_LAP_values_1              0.009447
#  RE_linear_values_1           0.246447
#  RE_linear_LAP_values_1       0.241635
#  VALUE_PDT_2               8268.195544
#  VALUE_FQ_2                7108.951934
#  VALUE_SMQ_2               7831.892925
#  RE_FQ_2                      0.002650
#  RE_linear_FQ_2               0.251153
#  RE_SMQ_2                     0.002202
#  RE_linear_SMQ_2              0.246545
#  dtype: float64,
#  RE_values_1                  0.001186
#  RE_LAP_values_1              0.009179
#  RE_linear_values_1           0.246457
#  RE_linear_LAP_values_1       0.238285
#  VALUE_PDT_2               8936.479803
#  VALUE_FQ_2                7703.045536
#  VALUE_SMQ_2               8457.988903
#  RE_FQ_2                      0.002602
#  RE_linear_FQ_2               0.251961
#  RE_SMQ_2                     0.001978
#  RE_linear_SMQ_2              0.244103
#  dtype: float64,
#  RE_values_1                  0.001230
#  RE_LAP_values_1              0.008915
#  RE_linear_values_1           0.246588
#  RE_linear_LAP_values_1       0.240008
#  VALUE_PDT_2               9601.012305
#  VALUE_FQ_2                8297.359202
#  VALUE_SMQ_2               9074.584963
#  RE_FQ_2                      0.002550
#  RE_linear_FQ_2               0.252254
#  RE_SMQ_2                     0.002048
#  RE_linear_SMQ_2              0.244385
#  dtype: float64,
#  RE_values_1                   0.001195
#  RE_LAP_values_1               0.008312
#  RE_linear_values_1            0.246442
#  RE_linear_LAP_values_1        0.241186
#  VALUE_PDT_2               10261.557838
#  VALUE_FQ_2                 8892.578906
#  VALUE_SMQ_2                9689.041636
#  RE_FQ_2                       0.002600
#  RE_linear_FQ_2                0.252052
#  RE_SMQ_2                      0.001932
#  RE_linear_SMQ_2               0.241937
#  dtype: float64,
#  RE_values_1                   0.001165
#  RE_LAP_values_1               0.007916
#  RE_linear_values_1            0.246669
#  RE_linear_LAP_values_1        0.242080
#  VALUE_PDT_2               10918.107722
#  VALUE_FQ_2                 9488.968238
#  VALUE_SMQ_2               10298.085058
#  RE_FQ_2                       0.002528
#  RE_linear_FQ_2                0.251629
#  RE_SMQ_2                      0.001866
#  RE_linear_SMQ_2               0.243361
#  dtype: float64,
#  RE_values_1                   0.001180
#  RE_LAP_values_1               0.007294
#  RE_linear_values_1            0.247864
#  RE_linear_LAP_values_1        0.241217
#  VALUE_PDT_2               11570.478651
#  VALUE_FQ_2                10079.624919
#  VALUE_SMQ_2               10900.764815
#  RE_FQ_2                       0.002491
#  RE_linear_FQ_2                0.250230
#  RE_SMQ_2                      0.001775
#  RE_linear_SMQ_2               0.240559
#  dtype: float64,
#  RE_values_1                   0.001124
#  RE_LAP_values_1               0.006799
#  RE_linear_values_1            0.247234
#  RE_linear_LAP_values_1        0.239930
#  VALUE_PDT_2               12218.408362
#  VALUE_FQ_2                10673.209575
#  VALUE_SMQ_2               11502.936871
#  RE_FQ_2                       0.002429
#  RE_linear_FQ_2                0.249671
#  RE_SMQ_2                      0.001865
#  RE_linear_SMQ_2               0.240691
#  dtype: float64,
#  RE_values_1                   0.001109
#  RE_LAP_values_1               0.006716
#  RE_linear_values_1            0.248146
#  RE_linear_LAP_values_1        0.243380
#  VALUE_PDT_2               12861.881589
#  VALUE_FQ_2                11264.982806
#  VALUE_SMQ_2               12107.092937
#  RE_FQ_2                       0.002416
#  RE_linear_FQ_2                0.248983
#  RE_SMQ_2                      0.001884
#  RE_linear_SMQ_2               0.240027
#  dtype: float64,
#  RE_values_1                   0.001072
#  RE_LAP_values_1               0.006624
#  RE_linear_values_1            0.248355
#  RE_linear_LAP_values_1        0.245077
#  VALUE_PDT_2               13500.484682
#  VALUE_FQ_2                11859.450879
#  VALUE_SMQ_2               12697.795243
#  RE_FQ_2                       0.002423
#  RE_linear_FQ_2                0.249490
#  RE_SMQ_2                      0.001851
#  RE_linear_SMQ_2               0.238783
#  dtype: float64]

# %%
# 使用 pd.concat 将平均值列表重新组合成一个数据框
result_df = pd.concat(averages_list, axis=1)
result_df_transposed = result_df.T
result_df_transposed
# Out:
#     RE_values_1  RE_LAP_values_1  RE_linear_values_1  RE_linear_LAP_values_1  \
# 0      0.002328         0.024715            0.264575                0.260995
# 1      0.001670         0.019786            0.252660                0.226123
# 2      0.001519         0.015292            0.253457                0.236770
# 3      0.001429         0.013931            0.255917                0.237210
# 4      0.001392         0.013915            0.255456                0.242043
# 5      0.001394         0.012175            0.257403                0.244656
# 6      0.001276         0.010272            0.254136                0.244371
# 7      0.001112         0.010166            0.252410                0.242251
# 8      0.001101         0.009902            0.252664                0.246822
# 9      0.001139         0.008862            0.252263                0.249009
# 10     0.001181         0.008843            0.249194                0.247297
# 11     0.001181         0.009447            0.246447                0.241635
# 12     0.001186         0.009179            0.246457                0.238285
# 13     0.001230         0.008915            0.246588                0.240008
# 14     0.001195         0.008312            0.246442                0.241186
# 15     0.001165         0.007916            0.246669                0.242080
# 16     0.001180         0.007294            0.247864                0.241217
# 17     0.001124         0.006799            0.247234                0.239930
# 18     0.001109         0.006716            0.248146                0.243380
# 19     0.001072         0.006624            0.248355                0.245077
#
#      VALUE_PDT_2    VALUE_FQ_2   VALUE_SMQ_2   RE_FQ_2  RE_linear_FQ_2  \
# 0     704.603651    592.782326    682.351003  0.003633        0.264657
# 1    1406.649002   1185.436815   1358.420167  0.003139        0.254200
# 2    2106.030590   1777.532694   2029.537073  0.002919        0.251118
# 3    2802.596044   2371.386173   2695.101438  0.002907        0.251552
# 4    3496.449059   2964.385629   3352.711777  0.002799        0.251191
# 5    4187.484389   3556.711965   4007.123314  0.002811        0.252257
# 6    4875.534411   4148.220767   4656.160302  0.002849        0.251552
# 7    5560.533094   4739.504369   5301.506989  0.002942        0.250981
# 8    6242.356160   5332.079811   5942.679043  0.002802        0.249704
# 9    6921.033827   5924.683005   6574.567324  0.002659        0.251041
# 10   7596.367548   6516.379944   7207.893958  0.002663        0.252117
# 11   8268.195544   7108.951934   7831.892925  0.002650        0.251153
# 12   8936.479803   7703.045536   8457.988903  0.002602        0.251961
# 13   9601.012305   8297.359202   9074.584963  0.002550        0.252254
# 14  10261.557838   8892.578906   9689.041636  0.002600        0.252052
# 15  10918.107722   9488.968238  10298.085058  0.002528        0.251629
# 16  11570.478651  10079.624919  10900.764815  0.002491        0.250230
# 17  12218.408362  10673.209575  11502.936871  0.002429        0.249671
# 18  12861.881589  11264.982806  12107.092937  0.002416        0.248983
# 19  13500.484682  11859.450879  12697.795243  0.002423        0.249490
#
#     RE_SMQ_2  RE_linear_SMQ_2
# 0   0.004766         0.258920
# 1   0.003274         0.271811
# 2   0.002861         0.254825
# 3   0.002523         0.241754
# 4   0.002303         0.249341
# 5   0.002375         0.249199
# 6   0.002314         0.250786
# 7   0.002106         0.248804
# 8   0.002261         0.249151
# 9   0.002237         0.246373
# 10  0.002191         0.245453
# 11  0.002202         0.246545
# 12  0.001978         0.244103
# 13  0.002048         0.244385
# 14  0.001932         0.241937
# 15  0.001866         0.243361
# 16  0.001775         0.240559
# 17  0.001865         0.240691
# 18  0.001884         0.240027
# 19  0.001851         0.238783

# %%
import matplotlib.pyplot as plt
# 实验一

# 选择要绘制的列
columns_to_plot = ['RE_values_1', 'RE_LAP_values_1']

# 预先设定不同列名对应的标签
column_labels = {'RE_values_1': 'BPPDT', 'RE_LAP_values_1': 'LAP'}

# 获取列名作为 x 轴数据
x_values = np.linspace(0, 1, len(result_df_transposed.index))

# 获取每列的平均值作为 y 轴数据，并乘以 100
for column in columns_to_plot:
    y_values = result_df_transposed[column] * 100
    
    # 绘制曲线
    plt.plot(x_values, y_values, label=column_labels.get(column, column))

# 设置 x 轴范围为 [0, 1]
plt.xlim(0, 1)

# 设置 x 轴标签
plt.xlabel('B_prime')

# 设置 y 轴标签
plt.ylabel('RE(%)')

# 添加图例
plt.legend()

# 显示图形
plt.show()

# %%
# 选择要绘制的列
columns_to_plot = ['RE_linear_values_1', 'RE_linear_LAP_values_1']

# 预先设定不同列名对应的标签
column_labels = {'RE_linear_values_1': 'BPPDT', 'RE_linear_LAP_values_1': 'LAP'}

# 获取列名作为 x 轴数据
x_values = np.linspace(0, 1, len(result_df_transposed.index))

# 获取每列的平均值作为 y 轴数据，并乘以 100
for column in columns_to_plot:
    y_values = result_df_transposed[column] * 100
    
    # 绘制曲线
    plt.plot(x_values, y_values, label=column_labels.get(column, column))

# 设置 x 轴范围为 [0, 1]
plt.xlim(0, 1)

# 设置 x 轴标签
plt.xlabel('B_prime')

# 设置 y 轴标签
plt.ylabel('RE(%)')

# 添加图例
plt.legend()

# 显示图形
plt.show()

# %%
# 实验二

# 选择要绘制的列
columns_to_plot = ['RE_values_1', 'RE_FQ_2', 'RE_SMQ_2']

# 预先设定不同列名对应的标签
column_labels = {'RE_values_1': 'BPPDT', 'RE_FQ_2': 'FQ', 'RE_SMQ_2':'SMQ'}

# 获取列名作为 x 轴数据
x_values = np.linspace(0, 1, len(result_df_transposed.index))

# 获取每列的平均值作为 y 轴数据，并乘以 100
for column in columns_to_plot:
    y_values = result_df_transposed[column] * 100
    
    # 绘制曲线
    plt.plot(x_values, y_values, label=column_labels.get(column, column))

# 设置 x 轴范围为 [0, 1]
plt.xlim(0, 1)

# 设置 x 轴标签
plt.xlabel('B_prime')

# 设置 y 轴标签
plt.ylabel('RE(%)')

# 添加图例
plt.legend()

# 显示图形
plt.show()

# %%
# 选择要绘制的列
columns_to_plot = ['RE_linear_values_1', 'RE_linear_FQ_2', 'RE_linear_SMQ_2']

# 预先设定不同列名对应的标签
column_labels = {'RE_linear_values_1': 'BPPDT', 'RE_linear_FQ_2': 'FQ', 'RE_linear_SMQ_2':'SMQ'}

# 获取列名作为 x 轴数据
x_values = np.linspace(0, 1, len(result_df_transposed.index))

# 获取每列的平均值作为 y 轴数据，并乘以 100
for column in columns_to_plot:
    y_values = result_df_transposed[column] * 100
    
    # 绘制曲线
    plt.plot(x_values, y_values, label=column_labels.get(column, column))

# 设置 x 轴范围为 [0, 1]
plt.xlim(0, 1)

# 设置 x 轴标签
plt.xlabel('B_prime')

# 设置 y 轴标签
plt.ylabel('RE(%)')

# 添加图例
plt.legend()

# 显示图形
plt.show()

# %%
# 选择要绘制的列
columns_to_plot = ['VALUE_PDT_2', 'VALUE_FQ_2', 'VALUE_SMQ_2']

# 预先设定不同列名对应的标签
column_labels = {'VALUE_PDT_2': 'BPPDT', 'VALUE_FQ_2': 'FQ', 'VALUE_SMQ_2':'SMQ'}

# 获取列名作为 x 轴数据
x_values = np.linspace(0, 1, len(result_df_transposed.index))

# 获取每列的平均值作为 y 轴数据，并乘以 100
for column in columns_to_plot:
    y_values = result_df_transposed[column] * 100
    
    # 绘制曲线
    plt.plot(x_values, y_values, label=column_labels.get(column, column))

# 设置 x 轴范围为 [0, 1]
plt.xlim(0, 1)

# 设置 x 轴标签
plt.xlabel('B_prime')

# 设置 y 轴标签
plt.ylabel('RE(%)')

# 添加图例
plt.legend()

# 显示图形
plt.show()
